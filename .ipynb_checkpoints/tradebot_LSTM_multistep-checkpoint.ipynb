# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/batu/anaconda3/envs/rnn/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

# %%
PATH = "tmp/df_1minute_1yearago"
df = pd.read_feather(PATH)

# %%
#import time
#for i in range(len(df)):
#    temp = df.iloc[i][6]
#    temp = temp[:-3]
#    temp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(int(temp)))
#    df.iloc[i][6] = temp    
#    print(temp)
#df.to_feather(PATH)

# %%
TRAIN_SPLIT = 400000

# %%
# all values to float (except date)
df_temp = df.drop(['open time','close time'], axis=1).astype('float')
df_temp.insert(loc= 0, column='open time', value=df['open time'])
df_temp.insert(loc= 6, column='close time', value=df['close time'])
df = df_temp

# %%
features_considered = ['open','close','high','low','volume']

# %%
features = df[features_considered]
features.index = df['close time']
features.head()
# Out:
#                         open    close     high      low     volume
# close time
# 2019-02-27 12:42:59  3822.81  3822.88  3822.98  3822.02  10.450780
# 2019-02-27 12:43:59  3822.88  3821.84  3822.90  3821.83  23.876892
# 2019-02-27 12:44:59  3821.86  3821.77  3822.75  3821.00  14.931546
# 2019-02-27 12:45:59  3821.50  3823.00  3823.08  3821.00  12.137765
# 2019-02-27 12:46:59  3822.77  3819.99  3822.96  3819.33  17.135062

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
tf.random.set_seed(13)
past_history = 720
future_target = 72
STEP = 6
BATCH_SIZE = 256
BUFFER_SIZE = 10000
EVALUATION_INTERVAL = 400
EPOCHS = 100

x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(72))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Train for 400 steps, validate for 50 steps
# Epoch 1/100
# 400/400 [==============================] - 34s 86ms/step - loss: 0.2764 - val_loss: 0.0434
# Epoch 2/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0845 - val_loss: 0.0362
# Epoch 3/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0461 - val_loss: 0.0792
# Epoch 4/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0464 - val_loss: 0.1198
# Epoch 5/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0556 - val_loss: 0.0145
# Epoch 6/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0410 - val_loss: 0.0193
# Epoch 7/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0323 - val_loss: 0.0299
# Epoch 8/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0269 - val_loss: 0.0446
# Epoch 9/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0396 - val_loss: 0.0121
# Epoch 10/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0379 - val_loss: 0.0169
# Epoch 11/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0254 - val_loss: 0.0212
# Epoch 12/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0273 - val_loss: 0.0650
# Epoch 13/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0309 - val_loss: 0.0091
# Epoch 14/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0367 - val_loss: 0.0128
# Epoch 15/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0206 - val_loss: 0.0110
# Epoch 16/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0276 - val_loss: 0.0297
# Epoch 17/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0256 - val_loss: 0.0143
# Epoch 18/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0350 - val_loss: 0.0157
# Epoch 19/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0179 - val_loss: 0.0120
# Epoch 20/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0275 - val_loss: 0.0171
# Epoch 21/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0219 - val_loss: 0.0111
# Epoch 22/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0340 - val_loss: 0.0176
# Epoch 23/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0162 - val_loss: 0.0108
# Epoch 24/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0273 - val_loss: 0.0194
# Epoch 25/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0208 - val_loss: 0.0092
# Epoch 26/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0316 - val_loss: 0.0208
# Epoch 27/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0145 - val_loss: 0.0094
# Epoch 28/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0274 - val_loss: 0.0118
# Epoch 29/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0217 - val_loss: 0.0086
# Epoch 30/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0282 - val_loss: 0.0272
# Epoch 31/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 32/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0273 - val_loss: 0.0132
# Epoch 33/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0231 - val_loss: 0.0084
# Epoch 34/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0249 - val_loss: 0.0249
# Epoch 35/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0125 - val_loss: 0.0100
# Epoch 36/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0265 - val_loss: 0.0121
# Epoch 37/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0245 - val_loss: 0.0090
# Epoch 38/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0222 - val_loss: 0.0206
# Epoch 39/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0120 - val_loss: 0.0084
# Epoch 40/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0260 - val_loss: 0.0113
# Epoch 41/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0256 - val_loss: 0.0105
# Epoch 42/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0200 - val_loss: 0.0333
# Epoch 43/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 44/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0232 - val_loss: 0.0110
# Epoch 45/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0257 - val_loss: 0.0139
# Epoch 46/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0185 - val_loss: 0.0180
# Epoch 47/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0156 - val_loss: 0.0253
# Epoch 48/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0211 - val_loss: 0.0083
# Epoch 49/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0265 - val_loss: 0.0101
# Epoch 50/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0167 - val_loss: 0.0112
# Epoch 51/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0168 - val_loss: 0.0251
# Epoch 52/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0194 - val_loss: 0.0121
# Epoch 53/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0273 - val_loss: 0.0106
# Epoch 54/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0152 - val_loss: 0.0084
# Epoch 55/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0179 - val_loss: 0.0111
# Epoch 56/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0178 - val_loss: 0.0083
# Epoch 57/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0281 - val_loss: 0.0117
# Epoch 58/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0143 - val_loss: 0.0098
# Epoch 59/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0186 - val_loss: 0.0111
# Epoch 60/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0165 - val_loss: 0.0107
# Epoch 61/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0284 - val_loss: 0.0123
# Epoch 62/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0136 - val_loss: 0.0089
# Epoch 63/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0191 - val_loss: 0.0190
# Epoch 64/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0171 - val_loss: 0.0106
# Epoch 65/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0273 - val_loss: 0.0145
# Epoch 66/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0128 - val_loss: 0.0085
# Epoch 67/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0197 - val_loss: 0.0202
# Epoch 68/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0192 - val_loss: 0.0124
# Epoch 69/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0247 - val_loss: 0.0141
# Epoch 70/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0120 - val_loss: 0.0101
# Epoch 71/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0201 - val_loss: 0.0239
# Epoch 72/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0212 - val_loss: 0.0113
# Epoch 73/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0220 - val_loss: 0.0137
# Epoch 74/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0118 - val_loss: 0.0096
# Epoch 75/100
# 400/400 [==============================] - 31s 79ms/step - loss: 0.0199 - val_loss: 0.0145
# Epoch 76/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.0231 - val_loss: 0.0111
# Epoch 77/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0199 - val_loss: 0.0171
# Epoch 78/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0116 - val_loss: 0.0086
# Epoch 79/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0197 - val_loss: 0.0114
# Epoch 80/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0244 - val_loss: 0.0099
# Epoch 81/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0181 - val_loss: 0.0186
# Epoch 82/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0128 - val_loss: 0.0106
# Epoch 83/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0186 - val_loss: 0.0099
# Epoch 84/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0245 - val_loss: 0.0094
# Epoch 85/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0170 - val_loss: 0.0104
# Epoch 86/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 87/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0177 - val_loss: 0.0081
# Epoch 88/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0252 - val_loss: 0.0273
# Epoch 89/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0155 - val_loss: 0.0107
# Epoch 90/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0147 - val_loss: 0.0113
# Epoch 91/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0168 - val_loss: 0.0095
# Epoch 92/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0260 - val_loss: 0.0137
# Epoch 93/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0142 - val_loss: 0.0082
# Epoch 94/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0155 - val_loss: 0.0104
# Epoch 95/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0160 - val_loss: 0.0113
# Epoch 96/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0267 - val_loss: 0.0106
# Epoch 97/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.0136 - val_loss: 0.0083
# Epoch 98/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0166 - val_loss: 0.0184
# Epoch 99/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0152 - val_loss: 0.0113
# Epoch 100/100
# 400/400 [==============================] - 32s 80ms/step - loss: 0.0271 - val_loss: 0.0114

# %%
jtplot.reset()
def create_time_steps(length):
  return list(range(-length, 0))

def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

for x, y in val_data_multi.take(15):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
